# %% [markdown]
# # Program used for transitions of elongation rates, fluorescence intensities and fluorescence ratio
#
# This program are used in Figure 2B-G, S5B, S7C and 4B-E.

# %% [markdown]
# ## Figure 2B-G
#
# The transitions of mCherry-CAT fluorescence intensities and cell size in single-cell lineages.

# %% [markdown]
# ### import packages

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import random
import os, sys
import glob
from common_function import singlecell as sc

# %% [markdown]
# ### Matplotlib setting

# %%
plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.preamble'] = [r'\usepackage{sansmath}', r'\sansmath'] 
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

plt.rcParams["font.size"] = 16.0

plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'

# %% [markdown]
# ### set variables

# %%
path_list = ['./single-cell_data/deletion_in_Cp/180726']
branch_path = path_list[0]
BL_time_Cp_time_list = pd.read_csv('./BL_time_Cp_time_data.csv')
BL_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'BL_time'].reset_index(drop = True)[0] ## slice number just after blue light exposure
Cp_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'Cp_time'].reset_index(drop = True)[0] ## slice number just after Cp exposure
if BL_time == 0:
    BL_time = Cp_time
window = 1/12 ## averaged time window (1/12 is non-averaged window)

# %% [markdown]
# ### import the result data.
# import and integrate the data in deletion experiment under Cp exposure.

# %%
image_path = branch_path
Number = os.listdir(image_path + '/integrated')
Number = [i for i in Number if 'Results' in i]
for i in range(len(Number)):
    Number[i] = Number[i].lstrip('Results')
    Number[i] = Number[i].rstrip('.csv')
Result_all = sc.Read_results_data(Number, dr = image_path)      

#Result_all = Result_all[(Result_all['Slice']<=BL_time-4)|(Result_all['Slice']>=BL_time)] ###exclude the data during BL illumination
Result_gen = sc.Modify_generation_data(Result_all,BL_time)
Result_gen.file = Result_gen.file.astype(str).str.zfill(4)

Result_gen['Time'] = (Result_gen['Slice']-BL_time)/6
Result_gen['Area2'] = Result_gen['Area']/237.16 ### transfrom from area (pixel) to area (µm^2)

# %% [markdown]
# ### plot and save figure
#
# (left) Transitions of mCherry-CAT fluorescence intensities
# (right) Transition of cell size
# Red represents non-deleted cell lineages. Green represents resistance-gene-deleted growth-halted cell lineages. Blue denotes resistance-gene-deleted growth-restored cell lineages.

# %%
sample_list = [['2012'],['3402'],['1721']] ### Result IDs used in this figure
title_list = ['Resistance-gene-deleted cell lineage \n(growth-halted)', 'Resistance-gene-deleted cell lineage \n(growth-restored)', 'Non-deleted cell lineage']
color_list = ['limegreen', 'royalblue', 'tomato']

fig, ax = plt.subplots(ncols = 2, nrows = 3, figsize = (12,6), sharex = True,sharey = 'col')
for num,i in enumerate([2,0,1]):
    for k in sample_list[i]:
        res_test = Result_gen[Result_gen.file == k]
        if k == '3402':
            res_test = res_test[res_test['Slice'] != 429] ### remove the data of the slice 429 because of high background.
        ax[num,0].plot(res_test.Time, res_test.TxRed, color = color_list[i])
        ax[num,1].plot(res_test.Time, res_test.Area2, color = color_list[i])
    ax[num,0].set_xlim(0,125)
    ax[num,0].set_ylim(-5,250)
    ax[num,1].set_xlim(0,125)
    ax[num,1].set_ylim(0,10)
    ax[num,0].text(15, 240, title_list[i], fontsize =16, va='top', ha='left')
ax[1,1].set_ylabel('Cell size ($\mu m^2$)', fontsize = 18)
ax[1,0].set_ylabel('mCherry-CAT fluorescence intensity (a.u.)', fontsize = 18)

fig.add_subplot(111, frameon=False)
# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
plt.xlabel('Time after BL exposure (h)', fontsize = 18)
plt.show()

# save_path = main_path + '/figure' + path_list[-1] + '/Generation_time_per_generation_sample.pdf'
# plt.savefig(save_path, transparent = True, bbox_inches = 'tight')
# plt.cla

# %% [markdown]
# ## Figure S5B

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os, sys
import glob
from common_function import singlecell as sc

#folder search
path = './single-cell_data/deletion_in_Cp'
path_list = glob.glob(os.path.join(path, '**/integrated'), recursive = True)
path_list = [x.replace(path,'').replace('/integrated','') for x in path_list]

# %% [markdown]
# ### Set variables

# %%
index_list = ['fluorescence_ratio', 'elongation_rate', 'RplS-mCherry', 'RpsB-YFP']
ylabel_list = ['Fluorescence ratio (a.u.)', 'Elongation rate (h$^{-1}$)', 'RplS-mCherry (a.u.)', 'RpsB-mVenus (a.u.)']
color_list = ['royalblue', 'limegreen', 'tomato', 'grey']
label_list = ['Resistance-gene-deleted \ncell lineages (growth-restored)', 'Resistance-gene-deleted \ncell lineages (growth-halted)', 'Non-deleted cell lineages', 'Pre-deleted cell lineages']
xlim_min = -5
xlim_max = 70
max_list = [4.0,1.05,500.0,500.0]
min_list = [0.0,-0.075,0.0,0.0]

# %%
Data_list = []
for k in [3,1]:
    branch_path = path_list[k]
    #Global variables

    BL_time_Cp_time_list = pd.read_csv('./BL_time_Cp_time_data.csv')
    BL_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'BL_time'].reset_index(drop = True)[0] ## slice number just after blue light exposure
    Cp_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'Cp_time'].reset_index(drop = True)[0] ## slice number just after Cp exposure
    if BL_time == 0:
        BL_time = Cp_time
    window = 1 ## averaged time window (1/12 is non-averaged window)


    ##Distinguish cell types
    image_path = path + branch_path
    Number = os.listdir(image_path + '/integrated')
    Number = [i for i in Number if 'Results' in i]
    for i in range(len(Number)):
        Number[i] = Number[i].lstrip('Results')
        Number[i] = Number[i].rstrip('.csv')

    Result_all = sc.Read_results_data(Number, dr = image_path)             

    id_list = sorted(Result_all['id_number'].drop_duplicates().tolist())
    for id_number in id_list:
        ## Combine result data
        Result = sc.All_Result_time_elongation(Result_all, id_number, directory = image_path, BL_time1 = BL_time, win = window, branch_path = branch_path)
        ## calculate 2SD of median 
        data = sc.Median_95percent_area_YK0083(Result)
        Data_list += [data]

# %% [markdown]
# ### plot and save figure

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize = (5.165,3.5))
for num,i in enumerate([1]):
    index = index_list[i]
    ylabel = ylabel_list[i]
    max_i = max_list[i]
    min_i = min_list[i]
    index_top = index + '_top'
    index_median = index + '_median'
    index_bottom = index + '_bottom'
    
    for data_index in [2,1,0,3]:
        if len(Data_list) == 1:
            Data = Data_list[0]
        else:
            Data = Data_list[data_index]
        color = color_list[data_index]
        label = label_list[data_index]
        ax.plot(Data['Time'],Data[index_median], color = color, label = label)
        ax.fill_between(Data['Time'],Data[index_top],Data[index_bottom],color = color,alpha = 0.25,zorder = 7)
    ax.set_ylabel(ylabel, fontsize = 18)
    ax.vlines(0,-5,max_i,zorder = 10)
    ax.set_ylim(min_i,max_i)
    ax.set_xlim(xlim_min,xlim_max)
    ax.set_xticks([0,10,20,30,40,50,60,70])
    ax.set_xticklabels([0,'',20,'',40,'',60,''])
    ax.set_yticks([0.0,0.25,.5,.75,1.0])
    ax.set_yticklabels([0.0,'',0.5,'',1.0])
    #ax.hlines(0,-5,70,zorder=1)
ax.set_xlabel('Time after BL exposure (h)', fontsize = 18)
ax.legend(bbox_to_anchor=(2.08, 0.05), loc = 'lower right',fontsize = 16)
plt.show()
# save_path = './FigureS5B.pdf'
# plt.savefig(save_path, transparent = True, bbox_inches = 'tight')
# plt.cla()

# %% [markdown]
# ## Figure S7C
# Representative single-cell lineages of mCherry-CAT fluorescent intensity and cell size.

# %% [markdown]
# ### Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import single-cell data

# %%
path = './single-cell_data/Cp_removal/181026/integrated'
data1 = pd.read_csv(path + '/Results3511.csv')

data1['Time'] = (data1['Slice'] - 17)/6
data1['Area2'] = data1['Area']/237.16
data1['TxRed'] = data1['Mean_TxRed'] - data1['Background_TxRed']
data1 = data1[(data1['Time']<-0.5)|(data1['Time']>=0.0)]

data2 = pd.read_csv(path + '/Results3503.csv')

data2['Time'] = (data2['Slice'] - 17)/6
data2['Area2'] = data2['Area']/237.16
data2['TxRed'] = data2['Mean_TxRed'] - data2['Background_TxRed']
data2 = data2[(data2['Time']<-0.5)|(data2['Time']>=0.0)]

# %% [markdown]
# ### Set Matplotlib parameters

# %%
plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.preamble'] = [r'\usepackage{sansmath}', r'\sansmath'] 
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

plt.rcParams["font.size"] = 16.0

plt.rcParams['xtick.direction'] = 'out'
plt.rcParams['ytick.direction'] = 'out'

# %% [markdown]
# ### plot and save figure

# %%
title_list = ['Resistance-gene-deleted cell \nlineage (growth-halted)', 'Resistance-gene-deleted cell \nlineage (growth-restored)', 'Non-deleted cell lineage']
color_list = ['limegreen','royalblue','tomato']
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (12,4), sharex = True)
ax[0,1].plot(data1['Time'], data1['Area2'],color = color_list[0])
ax[0,0].plot(data1['Time'], data1['TxRed'],color = color_list[0])
ax[1,1].plot(data2['Time'], data2['Area2'],color = color_list[1])
ax[1,0].plot(data2['Time'], data2['TxRed'],color = color_list[1])

for i in np.arange(0,4,1):
    if i%2 == 1:
        k, j = 0.0, 10.0
    else:
        k, j = -5.0, 125.0
    ax[i//2,i%2].vlines(0,k,j)
    ax[i//2,i%2].vlines(72,k,j,linestyle = 'dashed')
    ax[i//2,i%2].set_ylim(k,j)
    ax[i//2,i%2].set_xlim(-2.5,90)
    ax[i//2,i%2].text(75,j*0.85,'-Cp', fontsize =15, fontweight = 'bold')
    ax[i//2,i%2].text(2,j*0.85,'+Cp', fontsize =15, fontweight = 'bold')
    ax[i//2,i%2].fill_between((-2,72),(k,k),(j,j),color = 'lightgreen', alpha = 0.15)
    if i % 2 == 0:
        ax[i//2,0].text(5, 90, title_list[i//2], fontsize =13, va='top', ha='left')
        ax[i//2,0].set_yticks([0,50,100])
        ax[i//2,0].set_yticklabels(['0','','100'])
    elif i % 2 == 1:
        ax[i//2,1].set_yticks([0,5,10])
        ax[i//2,1].set_yticklabels(['0','','10'])
fig.text(0.5,0.0,'Time after BL exposure (h)', ha = 'center', fontsize = 18)
fig.text(0.49,0.5,'Cell size ($\mu m^2$)',  va= 'center', rotation='vertical', fontsize = 18)
fig.text(0.065,0.5,'mCherry-CAT\nfluorescence intensity (a.u.)', ha = 'center' ,va= 'center', rotation='vertical', fontsize = 18)
plt.show()
#save_path = './FigureS7C.pdf'
#plt.savefig(save_path, transparent = True, bbox_inches = 'tight')

# %% [markdown]
# ## Figure 4B-E

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os, sys
import glob
from common_function import singlecell as sc

#folder search
path = './single-cell_data/ribosome_reporter'
path_list = glob.glob(os.path.join(path, '**/integrated'), recursive = True)
path_list = [x.replace(path,'').replace('/integrated','') for x in path_list]

# %%
Data_list = []
for k in [4,0]:
    branch_path = path_list[k]
    #Global variables

    BL_time_Cp_time_list = pd.read_csv('./BL_time_Cp_time_data.csv')
    BL_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'BL_time'].reset_index(drop = True)[0] ## slice number just after blue light exposure
    Cp_time = BL_time_Cp_time_list.loc[BL_time_Cp_time_list['Date'] == int(branch_path[-6:]), 'Cp_time'].reset_index(drop = True)[0] ## slice number just after Cp exposure
    if BL_time == 0:
        BL_time = Cp_time
    window = 1 ## averaged time window (1/12 is non-averaged window)


    ##Distinguish cell types
    image_path = path + branch_path
    Number = os.listdir(image_path + '/integrated')
    Number = [i for i in Number if 'Results' in i]
    for i in range(len(Number)):
        Number[i] = Number[i].lstrip('Results')
        Number[i] = Number[i].rstrip('.csv')

    Result_all = sc.Read_results_data(Number, dr = image_path)      
    ##Calculate normalised term
    norm = sc.Calculate_normalize_term(Result_all, BL_time = BL_time, dr = image_path)             

    id_list = sorted(Result_all['id_number'].drop_duplicates().tolist())
    for id_number in id_list:
        ## Combine result data
        Result = sc.All_Result_time_elongation_fluorescence_ratio(Result_all, id_number, directory = image_path, BL_time1 = BL_time, normalized_ratio = norm, win = window)
        ## calculate 2SD of median 
        data = sc.Median_95percent_area(Result)
        Data_list += [data]

# %%
index_list = ['fluorescence_ratio', 'elongation_rate', 'RplS-mCherry', 'RpsB-YFP']
ylabel_list = ['Fluorescence ratio (a.u.)', 'Elongation rate (h$^{-1}$)', 'RplS-mCherry (a.u.)', 'RpsB-mVenus (a.u.)']
color_list = ['royalblue', 'limegreen', 'tomato', 'grey']
label_list = ['Resistance-gene-deleted \ncell lineages (growth-restored)', 'Resistance-gene-deleted \ncell lineages (growth-halted)', 'Non-deleted cell lineages', 'Pre-deleted cell lineages']
xlim_min = -5
xlim_max = 70
max_list = [4.0,1.0,500.0,500.0]
min_list = [0.0,-0.2,0.0,0.0]

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 1, figsize = (5.165,3.5))
for num,i in enumerate([1]):
    index = index_list[i]
    ylabel = ylabel_list[i]
    max_i = max_list[i]
    min_i = min_list[i]
    index_top = index + '_top'
    index_median = index + '_median'
    index_bottom = index + '_bottom'
    
    for data_index in [2,1,0,3]:
        if len(Data_list) == 1:
            Data = Data_list[0]
        else:
            Data = Data_list[data_index]
        color = color_list[data_index]
        label = label_list[data_index]
        ax.plot(Data['Time'],Data[index_median], color = color, label = label)
        ax.fill_between(Data['Time'],Data[index_top],Data[index_bottom],color = color,alpha = 0.25,zorder = 7)
    ax.set_ylabel(ylabel, fontsize = 18)
    ax.vlines(0,-5,max_i,zorder = 10)
    ax.set_ylim(min_i,max_i)
    ax.set_xlim(xlim_min,xlim_max)
    ax.set_xticks([0,10,20,30,40,50,60,70])
    ax.set_xticklabels([0,'',20,'',40,'',60,''])
    ax.set_yticks([0.0,0.25,.5,.75,1.0])
    ax.set_yticklabels([0.0,'',0.5,'',1.0])
ax.set_xlabel('Time after BL exposure (h)', fontsize = 18)
ax.legend(bbox_to_anchor=(2.08, 0.05), loc = 'lower right',fontsize = 16)
plt.show()
#save_path = './Figure4B.pdf'
#plt.savefig(save_path, transparent = True, bbox_inches = 'tight')
#plt.cla()

# %%
fig, ax = plt.subplots(ncols = 3, nrows = 1, figsize = (18,3.5))
plt.subplots_adjust(wspace=0.3, hspace=0.2)
for num,i in enumerate([2,3,0]):
    index = index_list[i]
    ylabel = ylabel_list[i]
    max_i = max_list[i]
    min_i = min_list[i]
    index_top = index + '_top'
    index_median = index + '_median'
    index_bottom = index + '_bottom'
    
    for data_index in [2,1,0,3]:
        if len(Data_list) == 1:
            Data = Data_list[0]
        else:
            Data = Data_list[data_index]
        color = color_list[data_index]
        label = label_list[data_index]
        ax[num].plot(Data['Time'],Data[index_median], color = color, label = label)
        ax[num].fill_between(Data['Time'],Data[index_top],Data[index_bottom],color = color,alpha = 0.25,zorder = 7)
    #ax.legend()
    ax[num].set_ylabel(ylabel, fontsize = 18)
    ax[num].vlines(0,-5,max_i,zorder = 10)
    #ax[num].hlines(0,xlim_min,xlim_max,zorder = 11)
    ax[num].set_ylim(min_i,max_i)
    ax[num].set_xlim(xlim_min,xlim_max)
    ax[num].set_xticks([0,10,20,30,40,50,60,70])
    ax[num].set_xticklabels([0,'',20,'',40,'',60,''])
ax[1].set_xlabel('Time after BL exposure (h)', fontsize = 18)
for k in [0,1]:
    ax[k].set_yticklabels([0,'',200,'',400,''])
plt.show()
#save_path = './Figure4CtoE.pdf'
#plt.savefig(save_path, transparent = True, bbox_inches = 'tight')
#plt.cla()
